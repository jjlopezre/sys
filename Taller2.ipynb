# %% [markdown]
# <a href="https://colab.research.google.com/github/jjlopezre/sys/blob/master/Taller2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Taller 2
# 2. representacion generalizada

# %% [markdown]
# 2.3 Encuentre el espectro $cn \in \mathbb{C}$ de la señal $x(t) = u(t)$ a través
# de la representación generalizada $x(t) = \sum\limits_{n=-\infty}^\infty{c_n \phi_n(t)}$
# para $\phi_n(t) = e^{jn\omega_o t}$: Realice una simulacion en Python para
# $t \in  [0; 2]$ y determine el error relativo para $n \in{0\pm1,\pm2}$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=15
T = 2  segundos de grafica
Fs = 100 
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,Nm)

#xo = np.concatenate((0*np.ones(int(Nm/2)), 1*np.ones(int(Nm/2))), axis=0)
xo= np.heaviside(tv,0)
plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = ((1)/(nv*1j*2*np.pi))*(-(-1)**nv +1) 
Cn[N] = 0 

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 15 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((Nm,2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)
Px = 0.5 # estimar según señal estudiada
suma=0
peso=0
for n in range(1,2):
  peso= ((1-(-1)**n )/(n*2*np.pi))**2
  suma= suma+peso
er= (1-(2*suma)/Px )*100
print(er)
Px = 1/2 # estimar según señal estudiada
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
# Out:
# 59.47152654306489
# interactive(children=(IntSlider(value=1, description='Na', max=15, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.pltest>

# %% [markdown]
# #3. Serie de Fourier
# 1. Calcular los coeficientes de la serie compleja, trignométrica
# y compacta de Fourier para las siguientes funciones, con
# $t \in  [-\pi, \pi]$ :

# %% [markdown]
# a) $t$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=15
T = 2*np.pi #3 segundos de grafica
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))

xo = tv

plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = (1j*(-1)**nv)/nv
Cn[N] = 0 

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 15 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)


Px = (np.pi**2)/3 # estimar según señal estudiada
suma=0
peso=0
for n in range(1,5):
  peso= (((-1)**n )/n)**2
  suma= suma+peso
er= 1-(2*suma)/Px
er

def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
# Out:
# interactive(children=(IntSlider(value=1, description='Na', max=15, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.pltest>

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
plt.plot(tv,xo,label = '$x(t)$')
plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# b) $|sin(t)|$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=30
T = 2*np.pi #3 segundos de grafica
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))

xo = abs(np.sin(tv))

plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = ((1/(2*np.pi))*((1-((-1)**(nv+1))/nv+1)+(1-(-1)**(nv-1))/nv-1))
Cn[N] = 0 
Cn[N+1]=0
Cn[N-1]=0

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 30 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)


Px = 1/2 # estimar según señal estudiada
Co= 2/np.pi
suma=0
peso=0
for n in range(2,5):
  peso= ((1/(2*np.pi))*((1-((-1)**(n+1))/(n+1))+(1-(-1)**(n-1))/(n-1)))**2
  suma= suma+peso
er= 1 -(Co**2 + 2*suma)/Px
er
N=5
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( abs(Cn[N])**2 + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
# Out:
# interactive(children=(IntSlider(value=1, description='Na', max=5, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.pltest>

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
plt.plot(tv,xo,label = '$x(t)$')
#plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# c) $sgn(t)$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=50
T = 2*np.pi # segundos de grafica
wo = 2*np.pi/T
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))

xo = np.sign(tv)

plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = (1j/nv*np.pi)*(((-1)**nv) -1)
Cn[N] = 0 

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)


Px = 1 # estimar según señal estudiada
suma=0
peso=0
for n in range(1,5):
  peso= ((1/(n*np.pi))*((-1)**n)-1)**2
  suma= suma+peso
er= 1-(2*suma)/Px
er
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( abs(Cn[N])**2 + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
# Out:
# interactive(children=(IntSlider(value=1, description='Na', max=50, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.pltest>

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
plt.plot(tv,xo,label = '$x(t)$')
#plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# d)$|\cos^2(t/2)|$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=20
T = 2*np.pi # segundos de grafica
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))

xo = abs(np.cos(tv/2)**2)

plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = (1/4*np.pi)*(np.sin(np.pi*(1+nv))/1+nv - np.sin(0*(1+nv))/1+nv  + np.sin(np.pi*(1-nv))/1-nv - np.sin(0*(1-nv))/1-nv)  
Cn[N+1]=1/4
Cn[N-1]=1/4
Cn[N] = 1/2

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 20 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)


Px = 3/8 # estimar según señal estudiada
suma=0
peso=0
co=1/4
for n in range(1,5):
  peso= ((1/4*np.pi)*(np.sin(np.pi*(1+n))/1+n - np.sin(0*(1+n))/1+n  + np.sin(np.pi*(1-n))/1-n - np.sin(0*(1-n))/1-n))**2
  suma= suma+peso
er= 1-(co**2 + 2*suma)/Px
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( abs(Cn[N])**2 + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
er
# Out:
# interactive(children=(IntSlider(value=1, description='Na', max=20, min=1), Output()), _dom_classes=('widget-in…
# 0.8333333333333334

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
plt.plot(tv,xo,label = '$x(t)$')
plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# e) $e^{jt/2}$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=20
T = 2*np.pi # segundos de grafica
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))

xo = np.exp(1j*tv/2)

plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = (1/(2*np.pi*1j*(1/2 -nv)))*(np.exp((1/2 -nv)*1j*np.pi)-np.exp((nv - 1/2)*1j*np.pi))
Cn[N] = (np.exp(1j*np.pi)-1)/(1j*np.pi*np.exp(1j*np.pi/2))

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 20 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)


Px = (np.exp(1j*2*np.pi)-1)/(2*1j*np.pi*np.exp(1j*np.pi)) # estimar según señal estudiada
suma=0
peso=0
for n in range(1,5):
  peso= ((1/(n*np.pi))*((-1)**n)-1)**2
  suma= suma+peso
er= 1-(2*suma)/Px
er
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( abs(Cn[N])**2 + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
# Out:
# interactive(children=(IntSlider(value=1, description='Na', max=20, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.pltest>

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
plt.plot(tv,xo,label = '$x(t)$')
plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# f) $t^2$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=20
T = 2*np.pi # segundos de grafica
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))

xo = tv**2

plt.plot(tv,xo,'r',linewidth=4)
plt.grid()
plt.xlabel("t[s]",fontsize = 14)
plt.ylabel("x(t)",fontsize = 14)

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = (2/nv**2)*((-1)**nv)
Cn[N] = (np.pi**2)/3

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 20 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)


Px = (np.pi**4) /5 # estimar según señal estudiada
co= np.pi**2 /3
suma=0
peso=0
for n in range(1,5):
  peso= (2/n**2)*((-1)**n)**2
  suma= suma+peso
er= 1-(co**2 +2*suma)/Px
er
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- ( abs(Cn[N])**2 + 2*np.sum(abs(Cn[N:N+Na+1])**2))/Px
    xe = phin[:,ind]@ Cn[ind] 
    plt.plot(tv,xe,color='b',label='xe')
    plt.plot(tv,xo,color='r',label='x')
    plt.title('Er=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltest,Na=(1,N,1))
# Out:
# interactive(children=(IntSlider(value=1, description='Na', max=20, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.pltest>

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
plt.plot(tv,xo,label = '$x(t)$')
plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# 3.3 Encuentre el espectro de Fourier, su magnitud y el
# error cuadrático medio de la representación para $n \in{0,\pm1,\pm2,\pm3,\pm4,\pm5}$ a partir de $x^"$ para la señal $x(t)$ en la figura 1 . Compruebe el espectro obtenido
# con la estimación a partir de $x(t)$ mediante una simulación
# en Python.

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
import warnings
from ipywidgets import interact,IntSlider
warnings.filterwarnings("ignore")

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

N=50
A=2
d1=1
d2=4
m= (A/d2-d1)
T = 2*np.pi # segundos de grafica
Fs = 1000 # 500 muestras por segundo Ajustar según señal estudiada
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))



#calcular espectro 
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector num armónicos
Cn = m*(T/(2*(nv**2)*np.pi**2))*(np.cos((2*np.pi*nv*d2)/T)-np.cos((2*np.pi*nv*d1)/T))
Cn[N] = 0

#graficar espectro
fig = plt.figure(figsize=(4,8))
plt.subplot(3,1,1)
plt.stem(nv, np.real(Cn), 'r')
plt.title(r'Re{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Re\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,2)
plt.stem(nv, np.imag(Cn), 'r')
plt.title(r'Im{Cn}')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$Im\{C_n\}$',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(3,1,3)
plt.stem(nv, abs(Cn), 'r')
plt.title(r'|Cn|')
plt.xlabel(r'$nw_o$[rad/s]',fontsize = 14)
plt.ylabel(r'$|C_n|$',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()
N = 50 #numero armonicos
wo = 2*np.pi/T # frecuencia fundamental
# %% definir bases
phin = np.zeros((int(Nm),2*N+1),dtype=np.complex_)
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)
#Error medio cuadratico
t= sym.symbols("t",Real = True)
px = (1/T)*sym.integrate((m*sym.DiracDelta(t+d2)-m*sym.DiracDelta(t+d1)-m*sym.DiracDelta(t-d1)+m*sym.DiracDelta(t-d2))**2,(t,-T/2,T/2))
suma=0
peso=0
for n in range(-5,0):
  peso=  (m*(T/(2*(n**2)*np.pi**2))*(np.cos((2*np.pi*n*d2)/T)-np.cos((2*np.pi*n*d1)/T)))**2
  suma= suma+peso
er= px-(2*suma)
er
# Out:
# 0.0795774715459477*DiracDelta(0) - 0.0745718449257503

# %%
xe = phin @ Cn  #producto matricial para calcular componentes espectrales phin.dot(Cn)
plt.plot(tv,xe,label = '$\hat{x}(t)$')
#plt.plot(tv,xo,label = '$x(t)$')
#plt.plot(tv,xo-xe,label = '$e(t)$')
plt.legend()

# %% [markdown]
# #4. Transformada de Fourier
# 1. Explique las semejanzas y diferencias entre la serie de Fourier
# (exponencial, trigonométrica y compacta) y la transformada
# de Fourier. Considere las diferentes combinaciones entre:
# espectro continuo y discreto y se˜nal en tiempo continuo y
# discreto. Además, consulte en qué consiste el algoritmo Fast
# Fourier Transform - (FFT) y su utilidad para el cálculo de la
# transformada discreta de Fourier. Compruebe los resultados
# obtenidos en el punto 1 utilizando la FFT en Python.

# %% [markdown]
# FFT para el 2.1

# %%
# Para graficar
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

T = 2*np.pi #3 segundos de grafica
Fs = 500 # 500 muestras por segundo
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))
wo= 2*np.pi/T
xo= np.exp(1j*Nm*wo*tv)
vf = np.fft.fftfreq(len(xo),1/Fs) #calculo vector de frecuencias
Xw = np.fft.fft(xo) #cálculo FFT

plt.stem(vf,abs(Xw),'r')
plt.title(r'|X[n]|')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|$',fontsize = 14)
plt.axis('tight')
plt.grid()
plt.show()
plt.stem(vf,abs(Xw)/len(vf),'r')
plt.title(r'|X[n]|/K=c_n')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|/K$',fontsize = 14)
# Out:
# Text(0, 0.5, '$|X[n]|/K$')

# %% [markdown]
# FFT para 2.2
# coseno

# %%
# Para graficar
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

T = 2*np.pi #3 segundos de grafica
Fs = 500 # 500 muestras por segundo
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))
wo= 2*np.pi/T
xo= np.cos(Nm*wo*tv)
vf = np.fft.fftfreq(len(xo),1/Fs) #calculo vector de frecuencias
Xw = np.fft.fft(xo) #cálculo FFT

plt.stem(vf,abs(Xw),'r')
plt.title(r'|X[n]|')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|$',fontsize = 14)
plt.axis('tight')
plt.grid()
plt.show()
plt.stem(vf,abs(Xw)/len(vf),'r')
plt.title(r'|X[n]|/K=c_n')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|/K$',fontsize = 14)
# Out:
# Text(0, 0.5, '$|X[n]|/K$')

# %% [markdown]
# seno

# %%
# Para graficar
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

T = 2*np.pi #3 segundos de grafica
Fs = 500 # 500 muestras por segundo
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))
wo= 2*np.pi/T
xo= np.sin(Nm*wo*tv)
vf = np.fft.fftfreq(len(xo),1/Fs) #calculo vector de frecuencias
Xw = np.fft.fft(xo) #cálculo FFT

plt.stem(vf,abs(Xw),'r')
plt.title(r'|X[n]|')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|$',fontsize = 14)
plt.axis('tight')
plt.grid()
plt.show()
plt.stem(vf,abs(Xw)/len(vf),'r')
plt.title(r'|X[n]|/K=c_n')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|/K$',fontsize = 14)
# Out:
# Text(0, 0.5, '$|X[n]|/K$')

# %% [markdown]
# FFT para el 2.3

# %%
# Para graficar
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

T = 2 #3 segundos de grafica
Fs = 500 # 500 muestras por segundo
Nm = T*Fs #numero de muestras requeridas
tv = np.linspace(-T/2,T/2,int(Nm))
wo= 2*np.pi/T
xo= np.heaviside(tv,0)
#xo= np.concatenate((np.ones(int(Nm/2)), 0*np.ones(int(Nm/2))), axis=0)
vf = np.fft.fftfreq(len(xo),1/Fs) #calculo vector de frecuencias
Xw = np.fft.fft(xo) #cálculo FFT

plt.stem(vf,abs(Xw),'r')
plt.title(r'|X[n]|')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|$',fontsize = 14)
plt.axis('tight')
plt.grid()
plt.show()
plt.stem(vf,abs(Xw)/len(vf),'r')
plt.title(r'|X[n]|/K=c_n')
plt.xlabel(r'$f$[Hz]',fontsize = 14)
plt.ylabel(r'$|X[n]|/K$',fontsize = 14)
# Out:
# Text(0, 0.5, '$|X[n]|/K$')
